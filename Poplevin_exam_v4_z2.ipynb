# %%
# !git clone https://github.com/Romzezz/Gradient_methods.git
# Out:
# Cloning into 'Gradient_methods'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 59 (delta 12), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (59/59), done.

# %%
from Gradient_methods.main import *

# %%
gradient_descent()
# Out:
#         Выберите метод решения:
#         1 - градиентный спуск с постоянным шагом
#         2 - градиентный спуск с дроблением шага
#         3 - наискорейший градиентный спуск
#         4 - алгоритм Ньютона-сопряженного градиента
#         Метод:
#         3
# Введите функцию в аналитическом виде: sin(x+y)+(x-y)**2-1.5*x+2.5*y+1
# Введите начальную точку: 0 0
# Введите точность оптимизации (оставьте пустым для значения по умолчанию):
# Введите максимальное количество итераций (оставьте пустым для значения по умолчанию):
# Показать промежуточные результаты? 1-да/0-нет: 0
# Визуализировать результат? 1-да/0-нет: 1
# /usr/local/lib/python3.7/dist-packages/sympy/utilities/lambdify.py:811: SymPyDeprecationWarning:
#
#
#
# The list of arguments is a `set`. This leads to unpredictable results
# has been deprecated since SymPy 1.6.3. Use : Convert set into list or
# tuple instead. See https://github.com/sympy/sympy/issues/20013 for
# more info.
# <html>
# ...
